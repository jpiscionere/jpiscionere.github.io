# %%
data_assesments=read.csv("/Users/jap/Downloads/anonymisedData/assessments.csv")
data_courses=read.csv("/Users/jap/Downloads/anonymisedData/courses.csv")
data_student_as=read.csv("/Users/jap/Downloads/anonymisedData/studentAssessment.csv")
data_student_reg=read.csv("/Users/jap/Downloads/anonymisedData/studentRegistration.csv")
data_stuVle=read.csv("/Users/jap/Downloads/anonymisedData/studentVle.csv")
data_stuInfo=read.csv("/Users/jap/Downloads/anonymisedData/studentInfo.csv")
data_vle=read.csv("/Users/jap/Downloads/anonymisedData/vle.csv")

# %%
summary(data_stuInfo)
length(which(data_stuInfo$code_module=='AAA' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='BBB' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='CCC' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='DDD' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='EEE' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='FFF' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
length(which(data_stuInfo$code_module=='GGG' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

npassed=c(531,3754,1678,2610,1650,3648,1514)
nreg=c(748,7909,4434,6272,2934,7762,2534)
avg_passed=npassed/nreg


a1=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2013B'))
a2=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2013J'))
a3=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2014B'))
a4=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2014J'))

b1=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2013B'))
b2=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2013J'))
b3=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2014B'))
b4=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2014J'))

c1=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2013B'))
c2=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2013J'))
c3=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2014B'))
c4=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2014J'))

d1=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2013B'))
d2=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2013J'))
d3=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2014B'))
d4=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2014J'))

e1=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2013B'))
e2=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2013J'))
e3=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2014B'))
e4=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2014J'))

f1=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2013B'))
f2=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2013J'))
f3=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2014B'))
f4=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2014J'))

g1=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2013B'))
g2=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2013J'))
g3=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2014B'))
g4=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2014J'))


ap1=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ap2=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ap3=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ap4=length(which(data_stuInfo$code_module=='AAA' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

bp1=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
bp2=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
bp3=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
bp4=length(which(data_stuInfo$code_module=='BBB' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

cp1=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
cp2=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
cp3=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
cp4=length(which(data_stuInfo$code_module=='CCC' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

dp1=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
dp2=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
dp3=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
dp4=length(which(data_stuInfo$code_module=='DDD' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

ep1=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ep2=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ep3=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
ep4=length(which(data_stuInfo$code_module=='EEE' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

fp1=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
fp2=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
fp3=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
fp4=length(which(data_stuInfo$code_module=='FFF' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))

gp1=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2013B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
gp2=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2013J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
gp3=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2014B' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
gp4=length(which(data_stuInfo$code_module=='GGG' & data_stuInfo$code_presentation=='2014J' & (data_stuInfo$final_result =="Pass" | data_stuInfo$final_result =="Distinction") ))
# Out:
#  code_module code_presentation   id_student      gender
#  AAA: 748    2013B: 4684       Min.   :   3733   F:14718
#  BBB:7909    2013J: 8845       1st Qu.: 508573   M:17875
#  CCC:4434    2014B: 7804       Median : 590310
#  DDD:6272    2014J:11260       Mean   : 706688
#  EEE:2934                      3rd Qu.: 644453
#  FFF:7762                      Max.   :2716795
#  GGG:2534
#                   region                        highest_education
#  Scotland            : 3446   A Level or Equivalent      :14045
#  East Anglian Region : 3340   HE Qualification           : 4730
#  London Region       : 3216   Lower Than A Level         :13158
#  South Region        : 3092   No Formal quals            :  347
#  North Western Region: 2906   Post Graduate Qualification:  313
#  West Midlands Region: 2582
#  (Other)             :14011
#     imd_band      age_band     num_of_prev_attempts studied_credits  disability
# ...

# %%
ap2
# Out:
# [1] 278

# %%
summary(data_assesments)
# Out:
#  code_module code_presentation id_assessment   assessment_type      date
#  AAA:12      2013B:39          Min.   : 1752   CMA : 76        Min.   : 12
#  BBB:42      2013J:53          1st Qu.:15023   Exam: 24        1st Qu.: 71
#  CCC:20      2014B:57          Median :25364   TMA :106        Median :152
#  DDD:35      2014J:57          Mean   :26474                   Mean   :145
#  EEE:15                        3rd Qu.:34892                   3rd Qu.:222
#  FFF:52                        Max.   :40088                   Max.   :261
#  GGG:30                                                        NA's   :11
#      weight
#  Min.   :  0.00
#  1st Qu.:  0.00
#  Median : 12.50
#  Mean   : 20.87
#  3rd Qu.: 24.25
#  Max.   :100.00

# %%
library('ggplot2')
library('ggmap')
qmap(location='uk',zoom=6)
library(corrplot)
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=uk&zoom=6&size=640x640&scale=2&maptype=terrain&language=en-EN
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=uk
# plot without title

# %%
latlon=geocode('East Anglian')
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=East%20Anglian

# %%
unique(data_stuInfo$region)
# Out:
#  [1] East Anglian Region  Scotland             North Western Region
#  [4] South East Region    West Midlands Region Wales
#  [7] North Region         South Region         Ireland
# [10] South West Region    East Midlands Region Yorkshire Region
# [13] London Region
# 13 Levels: East Anglian Region East Midlands Region Ireland ... Yorkshire Region

# %%
cities=data.frame(regions=unique(data_stuInfo$region),cities=c("Norfolk England","Glasgow Scotland","Manchester England","Dover England","Birmingham England",
                                                               "Cardiff Wales","Newcastle England","Brighton England","Dublin Ireland","Bristol England",
                                                                "Leicester England","Yorkshire England","London England"))
latlon=geocode(as.character(cities$cities))
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Norfolk%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Glasgow%20Scotland
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Manchester%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dover%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Birmingham%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Cardiff%20Wales
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Newcastle%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Brighton%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dublin%20Ireland
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Bristol%20England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Leicester%20England
# ...

# %%
cities$lat=latlon$lat
cities$lon=latlon$lon

# %%
a=as.data.frame(table(data_stuInfo$region))
cities$Freq=a$Freq

# %%
data_stuInfo$lat=c(1:length(data_stuInfo$region))*0 - 1
data_stuInfo$lon=c(1:length(data_stuInfo$region))*0 - 1
cities$lat[which(cities$regions==data_stuInfo$region[1])]
for(i in c(1:length(data_stuInfo$region))){
     data_stuInfo$lat[i]=cities$lat[which(cities$regions==data_stuInfo$region[i])]
     data_stuInfo$lon[i]=cities$lon[which(cities$regions==data_stuInfo$region[i])]

    }
# Out:
# [1] 52.61397

# %%
map <- get_map(location = c(lon = mean(cities$lon), lat = mean(cities$lat)), zoom = 6
               , source = "google")
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=52.713361,-1.735444&zoom=6&size=640x640&scale=2&maptype=terrain&language=en-EN

# %%
ggmap(map) + geom_point(data=cities,size=cities$Freq/100,color="red",alpha=0.3) +
annotate("text", x = cities$lon[which(cities$Freq!=1)], y = cities$lat[which(cities$Freq!=1)], 
         label = cities$Freq[which(cities$Freq!=1)]) + 
xlab("") + ylab("")
# Out:
# plot without title

# %%
#The Virtual Learning Environment is key to the open universities. Let's see if there's a correlation between the students who pass and the students who interact the most with the VLEs.

# %%
summary(data_stuVle)
length(unique(data_stuVle$id_student))
unique_ids=unique(data_stuVle$id_student)

avgclicks_AAA_1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='AAA')])



avgclicks_BBB=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='BBB')])/1567564
avgclicks_CCC=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='CCC')])/1207827
avgclicks_DDD=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='DDD')])/2166486
avgclicks_EEE=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='EEE')])/961433
avgclicks_FFF=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='FFF')])/4014499
avgclicks_GGG=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='GGG')])/387173


ac1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='AAA' & data_stuVle$code_presentation=='2013B')])
ac2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='AAA' & data_stuVle$code_presentation=='2013J')])
ac3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='AAA' & data_stuVle$code_presentation=='2014B')])
ac4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='AAA' & data_stuVle$code_presentation=='2014J')])

bc1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='BBB' & data_stuVle$code_presentation=='2013B')])
bc2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='BBB' & data_stuVle$code_presentation=='2013J')])
bc3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='BBB' & data_stuVle$code_presentation=='2014B')])
bc4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='BBB' & data_stuVle$code_presentation=='2014J')])

cc1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='CCC' & data_stuVle$code_presentation=='2013B')])
cc2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='CCC' & data_stuVle$code_presentation=='2013J')])
cc3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='CCC' & data_stuVle$code_presentation=='2014B')])
cc4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='CCC' & data_stuVle$code_presentation=='2014J')])

dc1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='DDD' & data_stuVle$code_presentation=='2013B')])
dc2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='DDD' & data_stuVle$code_presentation=='2013J')])
dc3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='DDD' & data_stuVle$code_presentation=='2014B')])
dc4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='DDD' & data_stuVle$code_presentation=='2014J')])

ec1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='EEE' & data_stuVle$code_presentation=='2013B')])
ec2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='EEE' & data_stuVle$code_presentation=='2013J')])
ec3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='EEE' & data_stuVle$code_presentation=='2014B')])
ec4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='EEE' & data_stuVle$code_presentation=='2014J')])

fc1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='FFF' & data_stuVle$code_presentation=='2013B')])
fc2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='FFF' & data_stuVle$code_presentation=='2013J')])
fc3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='FFF' & data_stuVle$code_presentation=='2014B')])
fc4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='FFF' & data_stuVle$code_presentation=='2014J')])

gc1=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='GGG' & data_stuVle$code_presentation=='2013B')])
gc2=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='GGG' & data_stuVle$code_presentation=='2013J')])
gc3=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='GGG' & data_stuVle$code_presentation=='2014B')])
gc4=sum(data_stuVle$sum_click[which(data_stuVle$code_module=='GGG' & data_stuVle$code_presentation=='2014J')])
# Out:
#  code_module   code_presentation   id_student         id_site
#  AAA: 350298   2013B:1886868     Min.   :   6516   Min.   : 526721
#  BBB:1567564   2013J:2988784     1st Qu.: 507743   1st Qu.: 673519
#  CCC:1207827   2014B:2160176     Median : 588236   Median : 730069
#  DDD:2166486   2014J:3619452     Mean   : 733334   Mean   : 738323
#  EEE: 961433                     3rd Qu.: 646484   3rd Qu.: 877030
#  FFF:4014499                     Max.   :2698588   Max.   :1049562
#  GGG: 387173
#       date          sum_click
#  Min.   :-25.00   Min.   :   1.000
#  1st Qu.: 25.00   1st Qu.:   1.000
#  Median : 86.00   Median :   2.000
#  Mean   : 95.17   Mean   :   3.717
#  3rd Qu.:156.00   3rd Qu.:   3.000
#  Max.   :269.00   Max.   :6977.000
# [1] 26074

# %%
summary(data_stuInfo)
length(data_stuInfo$id_student)
length(unique(data_stuInfo$id_student))
# Out:
#  code_module code_presentation   id_student      gender
#  AAA: 748    2013B: 4684       Min.   :   3733   F:14718
#  BBB:7909    2013J: 8845       1st Qu.: 508573   M:17875
#  CCC:4434    2014B: 7804       Median : 590310
#  DDD:6272    2014J:11260       Mean   : 706688
#  EEE:2934                      3rd Qu.: 644453
#  FFF:7762                      Max.   :2716795
#  GGG:2534
#                   region                        highest_education
#  Scotland            : 3446   A Level or Equivalent      :14045
#  East Anglian Region : 3340   HE Qualification           : 4730
#  London Region       : 3216   Lower Than A Level         :13158
#  South Region        : 3092   No Formal quals            :  347
#  North Western Region: 2906   Post Graduate Qualification:  313
#  West Midlands Region: 2582
#  (Other)             :14011
#     imd_band      age_band     num_of_prev_attempts studied_credits  disability
# ...

# %%
summary(data_vle)
# Out:
#     id_site        code_module code_presentation   activity_type
#  Min.   : 526721   AAA: 413    2013B:1251        resource :2660
#  1st Qu.: 661593   BBB:1154    2013J:1772        subpage  :1055
#  Median : 730096   CCC: 419    2014B:1671        oucontent: 996
#  Mean   : 726099   DDD:1708    2014J:1670        url      : 886
#  3rd Qu.: 814016   EEE: 336                      forumng  : 194
#  Max.   :1077905   FFF:1967                      quiz     : 127
#                    GGG: 367                      (Other)  : 446
#    week_from       week_to
#  Min.   : 0.0   Min.   : 0.00
#  1st Qu.: 8.0   1st Qu.: 8.00
#  Median :15.0   Median :15.00
#  Mean   :15.2   Mean   :15.21
#  3rd Qu.:22.0   3rd Qu.:22.00
#  Max.   :29.0   Max.   :29.00
#  NA's   :5243   NA's   :5243

# %%
length(which(data_vle$code_module == 'AAA' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'BBB' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'CCC' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'DDD' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'EEE' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'FFF' & data_vle$activity_type=='resource'))
length(which(data_vle$code_module == 'GGG' & data_vle$activity_type=='resource'))


activites=unique(data_vle$activity_type)
activites

table(data_vle$activity_type)

aa1=length(which(data_vle$code_module=='AAA'& data_vle$code_presentation=='2013B'))
aa2=length(which(data_vle$code_module=='AAA'& data_vle$code_presentation=='2013J'))
aa3=length(which(data_vle$code_module=='AAA'& data_vle$code_presentation=='2014B'))
aa4=length(which(data_vle$code_module=='AAA'& data_vle$code_presentation=='2014J'))

ba1=length(which(data_vle$code_module=='BBB'& data_vle$code_presentation=='2013B'))
ba2=length(which(data_vle$code_module=='BBB'& data_vle$code_presentation=='2013J'))
ba3=length(which(data_vle$code_module=='BBB'& data_vle$code_presentation=='2014B'))
ba4=length(which(data_vle$code_module=='BBB'& data_vle$code_presentation=='2014J'))

ca1=length(which(data_vle$code_module=='CCC'& data_vle$code_presentation=='2013B'))
ca2=length(which(data_vle$code_module=='CCC'& data_vle$code_presentation=='2013J'))
ca3=length(which(data_vle$code_module=='CCC'& data_vle$code_presentation=='2014B'))
ca4=length(which(data_vle$code_module=='CCC'& data_vle$code_presentation=='2014J'))

da1=length(which(data_vle$code_module=='DDD'& data_vle$code_presentation=='2013B'))
da2=length(which(data_vle$code_module=='DDD'& data_vle$code_presentation=='2013J'))
da3=length(which(data_vle$code_module=='DDD'& data_vle$code_presentation=='2014B'))
da4=length(which(data_vle$code_module=='DDD'& data_vle$code_presentation=='2014J'))

ea1=length(which(data_vle$code_module=='EEE'& data_vle$code_presentation=='2013B'))
ea2=length(which(data_vle$code_module=='EEE'& data_vle$code_presentation=='2013J'))
ea3=length(which(data_vle$code_module=='EEE'& data_vle$code_presentation=='2014B'))
ea4=length(which(data_vle$code_module=='EEE'& data_vle$code_presentation=='2014J'))

fa1=length(which(data_vle$code_module=='FFF'& data_vle$code_presentation=='2013B'))
fa2=length(which(data_vle$code_module=='FFF'& data_vle$code_presentation=='2013J'))
fa3=length(which(data_vle$code_module=='FFF'& data_vle$code_presentation=='2014B'))
fa4=length(which(data_vle$code_module=='FFF'& data_vle$code_presentation=='2014J'))

ga1=length(which(data_vle$code_module=='GGG'& data_vle$code_presentation=='2013B'))
ga2=length(which(data_vle$code_module=='GGG'& data_vle$code_presentation=='2013J'))
ga3=length(which(data_vle$code_module=='GGG'& data_vle$code_presentation=='2014B'))
ga4=length(which(data_vle$code_module=='GGG'& data_vle$code_presentation=='2014J'))
# Out:
# [1] 188
# [1] 807
# [1] 163
# [1] 706
# [1] 103
# [1] 454
# [1] 239
#  [1] resource       oucontent      url            homepage       subpage
#  [6] glossary       forumng        oucollaborate  dataplus       quiz
# [11] ouelluminate   sharedsubpage  questionnaire  page           externalquiz
# [16] ouwiki         dualpane       repeatactivity folder         htmlactivity
# 20 Levels: dataplus dualpane externalquiz folder forumng glossary ... url
#       dataplus       dualpane   externalquiz         folder        forumng
#             28             20             26              2            194
#       glossary       homepage   htmlactivity  oucollaborate      oucontent
#             21             22              4             82            996
#   ouelluminate         ouwiki           page  questionnaire           quiz
#             21             49            102             61            127
# repeatactivity       resource  sharedsubpage        subpage            url
# ...

# %%
final_frame=data.frame(
 code_module=unique(data_vle$code_module),
 avg_clicks=c(avgclicks_AAA,avgclicks_BBB,avgclicks_CCC,avgclicks_DDD,avgclicks_EEE,avgclicks_FFF,avgclicks_GGG),
 n_activities=c(413,1154,419,1708,336,1967,367),
 avg_passed,
 nreg
)

# %%
write.csv(final_frame,"RMIT_out.csv")

# %%
final_frame_2=data.frame(

 nreg=c(a1,a2,a3,a4,b1,b2,b3,b4,c1,c2,c3,c4,d1,d2,d3,d4,e1,e2,e3,e4,f1,f2,f3,f4,g1,g2,g3,g4),
 passed=c(ap1,ap2,ap3,ap4,bp1,bp2,bp3,bp4,cp1,cp2,cp3,cp4,dp1,dp2,dp3,dp4,ep1,ep2,ep3,ep4,fp1,fp2,fp3,fp4,
          gp1,gp2,gp3,gp4),
 n_activities=c(aa1,aa2,aa3,aa4,ba1,ba2,ba3,ba4,ca1,ca2,ca3,ca4,da1,da2,da3,da4,ea1,ea2,ea3,ea4,fa1,fa2,fa3,fa4,
                ga1,ga2,ga3,ga4),
 n_clicks=c(ac1,ac2,ac3,ac4,bc1,bc2,bc3,bc4,cc1,cc2,cc3,cc4,dc1,dc2,dc3,dc4,ec1,ec2,ec3,ec4,fc1,fc2,fc3,fc4,
            gc1,gc2,gc3,gc4),
     code_module=c("AAA","AAA","AAA","AAA",
              "BBB","BBB","BBB","BBB",
              "CCC","CCC","CCC","CCC",
              "DDD","DDD","DDD","DDD",
              "EEE","EEE","EEE","EEE",
              "FFF","FFF","FFF","FFF",
              "GGG","GGG","GGG","GGG")
 #codes=rep(c("2013B","2013J","2014B","2014J") ,7)
    
)

final_frame_2$passed=final_frame_2$passed/final_frame_2$nreg

# %%
write.csv(final_frame_2,"/Users/jap/Desktop/RMIT/RMIT_out.csv",row.names=FALSE)

# %%
library('GGally')
ggpairs(final_frame_2, columns = 2:5, ggplot2::aes(colour=code_module),diag="blank",
       columnLabels=c("Students Registered","% Students Passed","VLE Activities","VLE Clicks")) +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 6 rows containing missing values”Warning message:
# “Removed 6 rows containing missing values (geom_point).”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 6 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 6 rows containing missing values”Warning message:
# “Removed 6 rows containing missing values (geom_point).”Warning message:
# “Removed 6 rows containing missing values (geom_point).”
# plot without title

# %%
# Out:
#  [1] 2013J 2014J 2013B 2014B 2013J 2014J 2013B 2014B 2013J 2014J 2013B 2014B
# [13] 2013J 2014J 2013B 2014B
# Levels: 2013B 2013J 2014B 2014J
